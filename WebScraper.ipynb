# %%
import urllib.request as url
import bs4 as bs

# %%
sauce = url.urlopen('https://en.wikipedia.org/wiki/Main_Page')

# %%
soup = bs.BeautifulSoup(sauce,'lxml')

# %%
for url in soup.find_all('a'):
    print(url.get('href'))
# Out:
# None
# #mw-head
# #p-search
# /wiki/Wikipedia
# /wiki/Free_content
# /wiki/Encyclopedia
# /wiki/Wikipedia:Introduction
# /wiki/Special:Statistics
# /wiki/English_language
# /wiki/Portal:Arts
# /wiki/Portal:Biography
# /wiki/Portal:Geography
# /wiki/Portal:History
# /wiki/Portal:Mathematics
# /wiki/Portal:Science
# /wiki/Portal:Society
# /wiki/Portal:Technology
# /wiki/Portal:Contents/Portals
# /wiki/File:Jason_Isaacs_by_Gage_Skidmore.jpg
# /wiki/Nightswimming_(Awake)
# /wiki/Police_procedural
# /wiki/Awake_(TV_series)
# /wiki/NBC
# /wiki/Leonard_Chang
# /wiki/Davey_Holmes
# /wiki/Jeffrey_Reiner
# /wiki/Jason_Isaacs
# /wiki/Michael_Britten
# /wiki/Hannah_Britten
# /wiki/Laura_Allen
# /wiki/Rex_Britten
# /wiki/Dylan_Minnette
# /wiki/Ayelet_Zurer
# /wiki/United_States_Federal_Witness_Protection_Program
# /wiki/Oregon
# /wiki/Otis_Redding
# /wiki/Nightswimming_(Awake)
# /wiki/DJ_AM
# /wiki/Casey_Stengel
# /wiki/Lady_Gaga
# /wiki/Wikipedia:Today%27s_featured_article/March_2018
# ...
